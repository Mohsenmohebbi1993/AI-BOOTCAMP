# %% [markdown]
# # Online Class 1
#
# 1. Python
#
# * Operators in Python
# * Type
# * List, Tupel, Dic, set
# * Type Casting
# * String Method
# * List method
# * Tupel method
# * Dic method
# * set method
# * `if` `elif` `else`
# * Loop: `for` and `while`
# * `replace` , `split` , `strip`, slicing
# * Function: `def`
# *
#
# 2. OOp and Inheritance

# %%
print("Hi")
# Out:
# Hi

# %% [markdown]
# run in terminal
# pip freeze
# pip install pandas

# %%
# run in terminal
pip freeze
pip install pandas

# %% [markdown]
# If have not internet, can use
# https://runflare.com/mirrors/
#
# pip install -i https://mirror-pypi.runflare.com/simple django

# %% [markdown]
# Vevn
#
# in termminal:
#
# *`python -m venv name_of_venv`*
#
# python -m venv venv
#
# venv\Scripts\activate
#
# pip freeze     <--- package installed
#
# pip install numpy
