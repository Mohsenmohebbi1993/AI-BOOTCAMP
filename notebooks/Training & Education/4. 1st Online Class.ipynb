# %% [markdown]
# # Online Class 1
#
# 1. Python
#
# * Operators in Python
# * Type
# * List, Tupel, Dic, set
# * Type Casting
# * String Method
# * List method
# * Tupel method
# * Dic method
# * set method
# * `if` `elif` `else`
# * Loop: `for` and `while`
# * `replace` , `split` , `strip`, slicing
# * Function: `def`
# *
#
# 2. OOp and Inheritance
