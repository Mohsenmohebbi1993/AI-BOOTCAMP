# %% [markdown]
# # Tensor

# %%
import torch
import numpy as np

# %% [markdown]
# versio of torch

# %%
torch.__version__
# Out:
# '2.12.1+cu126'

# %%
tensor1d = torch.tensor([1, -1, 15, 1000])
print(tensor1d)
# Out:
# tensor([   1,   -1,   15, 1000])
