# %% [markdown]
# # 1. Python 1st

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Operators in Python

# %%
print("Number is 10")
x = 10
print(f"{x} + 2 = {10 + 2}\n{x} - 2 = {10 - 2}\n{x} * 2 = {10 * 2}\n{x} / 2 = {10 / 2}")
print(f"{x} // 4 = {10 // 4}\n{x} % 4 = {10 % 4}")
# Out:
# Number is 10
# 10 + 2 = 12
# 10 - 2 = 8
# 10 * 2 = 20
# 10 / 2 = 5.0
# 10 // 4 = 2
# 10 % 4 = 2
