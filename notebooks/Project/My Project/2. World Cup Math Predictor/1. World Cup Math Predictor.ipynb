# %% [markdown]
# # World Cup Math Predictor

# %% [markdown]
# [International Results Dataset](https://github.com/martj42/international_results/tree/master)

# %% [markdown]
# This dataset includes 49,459 results of international football matches starting from the very first official match in 1872 up to 2024. The matches range from FIFA World Cup to FIFI Wild Cup to regular friendly matches. The matches are strictly men's full internationals and the data does not include Olympic Games or matches where at least one of the teams was the nation's B-team, U-23 or a league select team.
#
# ## Dataset Description
#
# ### `results.csv`
# This file includes the following columns:
#
# - `date`: date of the match
# - `home_team`: the name of the home team
# - `away_team`: the name of the away team
# - `home_score`: full-time home team score including extra time, not including penalty shootouts
# - `away_score`: full-time away team score including extra time, not including penalty shootouts
# - `tournament`: the name of the tournament
# - `city`: the name of the city, town, or administrative unit where the match was played
# - `country`: the name of the country where the match was played
# - `neutral`: `TRUE`/`FALSE` indicating whether the match was played at a neutral venue
#
# ### `shootouts.csv`
# This file includes the following columns:
#
# - `date`: date of the match
# - `home_team`: the name of the home team
# - `away_team`: the name of the away team
# - `winner`: winner of the penalty shootout
# - `first_shooter`: the team that went first in the shootout
#
# ### `goalscorers.csv`
# This file includes the following columns:
#
# - `date`: date of the match
# - `home_team`: the name of the home team
# - `away_team`: the name of the away team
# - `team`: name of the team scoring the goal
# - `scorer`: name of the player scoring the goal
# - `own_goal`: whether the goal was an own goal
# - `penalty`: whether the goal was a penalty
#
#
# Note on team and country names: For home and away teams the current name of the team has been used. For example, when in 1882 a team who called themselves Ireland played against England, in this dataset, it is called Northern Ireland because the current team of Northern Ireland is the successor of the 1882 Ireland team. This is done so it is easier to track the history and statistics of teams.
#
# For country names, the name of the country at the time of the match is used. So when Ghana played in Accra, Gold Coast in the 1950s, even though the names of the home team and the country don't match, it was a home match for Ghana. This is indicated by the neutral column, which says FALSE for those matches, meaning it was not at a neutral venue.

# %% [markdown]
# ## Inspiration
#
# Some possible directions for exploring the data:
#
# - Who is the best team of all time?
# - Which teams dominated different eras of football?
# - What trends have appeared in international football over time, such as home advantage, total goals scored, or the distribution of team strength?
# - Can we learn anything about geopolitics from football fixtures? For example:
#   - How has the number of countries changed over time?
#   - Which teams tend to play each other most often?
# - Which countries host the most matches in which they are not participating themselves?
# - How much, if at all, does hosting a major tournament improve a country's chances in that tournament?
# - Which teams are the most active in playing friendlies and friendly tournaments, and does that help or hurt them?

# %%
import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats

import datetime

# %% [markdown]
# ## 1. Read data

# %%
csv_files = [f.replace(".csv","") for f in os.listdir() if f.endswith('.csv')]
for name_data in csv_files:
    globals()[name_data] = pd.read_csv(f"{name_data}.csv")

print(f"Name of dataframe\n{csv_files}")
# Out:
# Name of dataframe
# ['former_names', 'goalscorers', 'results', 'shootouts']

# %%
# drop null value
results.dropna(axis=0, inplace=True)

# %%
results
# Out:
#              date  home_team    away_team  home_score  away_score  \
# 0      1872-11-30   Scotland      England         0.0         0.0
# 1      1873-03-08    England     Scotland         4.0         2.0
# 2      1874-03-07   Scotland      England         2.0         1.0
# 3      1875-03-06    England     Scotland         2.0         2.0
# 4      1876-03-04   Scotland      England         3.0         0.0
# ...           ...        ...          ...         ...         ...
# 49513  2026-07-10      Spain      Belgium         2.0         1.0
# 49514  2026-07-11     Norway      England         1.0         2.0
# 49515  2026-07-11  Argentina  Switzerland         3.0         1.0
# 49516  2026-07-14     France        Spain         0.0         2.0
# 49517  2026-07-15    England    Argentina         1.0         2.0
#
#            tournament           city        country  neutral
# 0            Friendly        Glasgow       Scotland    False
# ...
